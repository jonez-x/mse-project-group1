# %%
# Re-importing required modules after code execution state reset
import random

# Re-define original entries
entries = [
    {
        "url": "https://images.unsplash.com/photo-1519389950473-47ba0277781c?w=800",
        "favicon": "https://www.google.com/favicon.ico",
        "title": "Tech Innovation Hub",
        "description": "Dive into the cutting-edge world of technology where artificial intelligence meets human creativity. Discover groundbreaking innovations that are reshaping industries, from machine learning algorithms to quantum computing breakthroughs. This hub connects visionaries, developers, and entrepreneurs who are building the future of digital transformation and creating solutions that will impact millions of lives worldwide."
    },
    {
        "url": "https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=800",
        "favicon": "https://www.youtube.com/favicon.ico",
        "title": "Mountain Adventure",
        "description": "Breathtaking mountain peaks, crystal-clear alpine lakes, and panoramic vistas. Perfect escape for outdoor enthusiasts seeking adventure and tranquility in nature's untamed wilderness."
    },
    {
        "url": "https://images.unsplash.com/photo-1441974231531-c6227db76b6e?w=800",
        "favicon": "https://www.spotify.com/favicon.ico",
        "title": "Forest Serenity",
        "description": "Immerse yourself in the peaceful sanctuary of ancient forests where time seems to stand still and nature's symphony creates the perfect backdrop for meditation. These verdant woodlands offer winding paths through towering trees, hidden clearings filled with wildflowers, and the gentle sound of rustling leaves. Find inner peace as you breathe in the fresh forest air and discover the healing power of nature's embrace."
    },
    {
        "url": "https://images.unsplash.com/photo-1449824913935-59a10b8d2000?w=800",
        "favicon": "https://www.netflix.com/favicon.ico",
        "title": "Urban Skyline",
        "description": "Modern cityscapes with architectural marvels and dazzling lights. Experience unlimited opportunities for exploration, career growth, and cultural adventures in metropolitan life."
    },
    {
        "url": "https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=800",
        "favicon": "https://www.github.com/favicon.ico",
        "title": "Ocean Waves",
        "description": "Therapeutic rhythm of endless waves crashing against pristine shores. Ultimate relaxation and spiritual renewal through the ocean's timeless dance and salt breeze."
    },
    {
        "url": "https://images.unsplash.com/photo-1518837695005-2083093ee35b?w=800",
        "favicon": "https://www.twitter.com/favicon.ico",
        "title": "Desert Sunset",
        "description": "Marvel at the spectacular golden hour as the sun sets over vast desert landscapes, painting the sky in brilliant oranges, purples, and reds that seem almost otherworldly. This arid wilderness showcases nature's resilience and beauty through unique rock formations, ancient cacti, and an endless horizon that stretches beyond imagination. The desert's silence and solitude offer profound moments of reflection and a deep connection with the Earth's raw, untouched magnificence."
    },
    {
        "url": "https://images.unsplash.com/photo-1470071459604-3b5ec3a7fe05?w=800",
        "favicon": "https://www.instagram.com/favicon.ico",
        "title": "Lake Reflection",
        "description": "Discover the perfect mirror of nature where crystal-clear lake waters create stunning reflections of surrounding mountains, clouds, and forests, doubling the beauty of every landscape. This serene aquatic environment provides ideal conditions for photography, contemplation, and peaceful moments away from life's chaos. The still waters host diverse wildlife and offer recreational activities like kayaking, fishing, and lakeside camping under star-filled skies that reflect perfectly in the glassy surface."
    },
    {
        "url": "https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=800",
        "favicon": "https://www.linkedin.com/favicon.ico",
        "title": "Professional Growth",
        "description": "Career development through networking, skill building, and mentorship opportunities. Build connections and achieve your professional goals in collaborative environments."
    },
    {
        "url": "https://images.unsplash.com/photo-1441974231531-c6227db76b6e?w=800",
        "favicon": "https://www.amazon.com/favicon.ico",
        "title": "Shopping Paradise",
        "description": "Enter a world of endless retail possibilities where cutting-edge products meet unbeatable prices and customer satisfaction is the top priority. This shopping destination features everything from innovative gadgets and fashion-forward clothing to home essentials and rare collectibles. With lightning-fast delivery, excellent customer service, and a vast marketplace that connects buyers with sellers worldwide, this platform has revolutionized how we discover, compare, and purchase products that enhance our daily lives."
    },
    {
        "url": "https://images.unsplash.com/photo-1519389950473-47ba0277781c?w=800",
        "favicon": "https://www.reddit.com/favicon.ico",
        "title": "Community Hub",
        "description": "Join vibrant online communities sharing knowledge and experiences. Connect with diverse voices and find meaningful discussions on virtually every topic imaginable."
    }
]

# Sample words to include in the word_dictionary
sample_words = ["technology", "nature", "travel", "food", "drink", "music", "community", "career", "shopping", "relaxation"]

# Function to create a random word dictionary with up to 3 words
def generate_word_dictionary():
    words = random.sample(sample_words, k=random.randint(1, 3))
    return {word: round(random.uniform(0.1, 1.0), 2) for word in words}

# Generate 100 entries with added word_dictionary
entries_with_words = []
for i in range(100):
    entry = entries[i % len(entries)].copy()
    entry["id"] = i + 1
    entry["word_dictionary"] = generate_word_dictionary()
    entries_with_words.append(entry)

# Preview first 5 results
entries_with_words[:5]
# Out:
# [{'url': 'https://images.unsplash.com/photo-1519389950473-47ba0277781c?w=800',
#   'favicon': 'https://www.google.com/favicon.ico',
#   'title': 'Tech Innovation Hub',
#   'description': 'Dive into the cutting-edge world of technology where artificial intelligence meets human creativity. Discover groundbreaking innovations that are reshaping industries, from machine learning algorithms to quantum computing breakthroughs. This hub connects visionaries, developers, and entrepreneurs who are building the future of digital transformation and creating solutions that will impact millions of lives worldwide.',
#   'id': 1,
#   'word_dictionary': {'relaxation': 0.13, 'travel': 0.5, 'technology': 0.84}},
#  {'url': 'https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=800',
#   'favicon': 'https://www.youtube.com/favicon.ico',
#   'title': 'Mountain Adventure',
# ...

# %%
# Out:
# Successfully exported 100 entries to entries.json
# File saved in the current directory.
